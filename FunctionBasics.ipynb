# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshucode93/GoogleColabsPractice/blob/main/FunctionBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Definition**
#
# A function is a block a code that performs a specific task. Functions help in organizing code, reusing code and improving readability.

# %%
# function declaration
def is_even(num):
  """
  This function checks whether a number is even or not
  input = interger
  output = even/odd
  """
  if num % 2 == 0:
    return 'even'
  else:
    return 'odd'

# %%
# function calling

# function_name(input)
is_even(21)
# Out:
# 'odd'

# %%
# accessing the doc string of a function
print(print.__doc__)
# Out:
# Prints the values to a stream, or to sys.stdout by default.
#
#   sep
#     string inserted between values, default a space.
#   end
#     string appended after the last value, default a newline.
#   file
#     a file-like object (stream); defaults to the current sys.stdout.
#   flush
#     whether to forcibly flush the stream.

# %% [markdown]
# ## **Parameters Vs Arguments**

# %% [markdown]
# **Types of Arguments**
#
# *   Default Arguments
# *   Positional Arguments
# *   Keyword Arguments

# %%
# Default Arguments
def power(a=1,b=1):
  return a**b

# %%
power()
# Out:
# 1

# %%
# Positional Arguments
power(2,6)
# Out:
# 64

# %%
# Keyword Arguments
power(b=6,a=2)
# Out:
# 64

# %% [markdown]
# # `*args and **kwargs `
#
# `*args and **kwargs` are special Python keywords that are used to pass the variable length of arguments to a function

# %%
# *args
# allows us to pass a variable number of non-keyword arguments to a function.

def multiply(*abc):
  product = 1

  for i in abc:
    product = product * i

  return product

# %%
multiply(1,2,43,6,2)
# Out:
# 1032

# %%
# **kwargs
# **kwargs allows us to pass any number of keyword arguments.
# Keyword arguments mean that they contain a key-value pair, like a Python dictionary.

def countrycapital(**kwargs):

  for (key,value) in kwargs.items():
    print(key,'->',value)

# %%
countrycapital(india='delhi',srilanka='colombo',nepal='kathmandu')
# Out:
# india -> delhi
# srilanka -> colombo
# nepal -> kathmandu

# %% [markdown]
# ### **Points to remember while using** `*args and **kwargs`
#
# *   order of the arguments matter(normal -> `*args` -> `**kwargs`)
# *   The words “args” and “kwargs” are only a convention, you can use any name of your choice

# %% [markdown]
# ### **How Functions are executed in memory?**

# %% [markdown]
# ## Without return statement

# %%
list = [1,2,3]
print(list.append(4))
print(list)
# Out:
# None
# [1, 2, 3, 4]

# %% [markdown]
# ## **Variable Scope**

# %%
def g(y):
    print(x)
    print(x+1)
x = 5
g(x)
print(x)

# %%
def f(y):
    x = 1
    x += 1
    print(x)
x = 5
f(x)
print(x)

# %%
def h(y):
    x += 1
x = 5
h(x)
print(x)

# %%
def f(x):
   x = x + 1
   print('in f(x): x =', x)
   return x

x = 3
z = f(x)
print('in main program scope: z =', z)
print('in main program scope: x =', x)

# %% [markdown]
# ## **Nested Functions**

# %%
def f():
  def g():
    print('inside function g')
  g()
  print('inside function f')

# %%
f()
# Out:
# inside function g
# inside function f

# %%
def g(x):
    def h():
        x = 'abc'
    x = x + 1
    print('in g(x): x =', x)
    h()
    return x

x = 3
z = g(x)

# %%
# type and id
def square(num):
  return num**2

type(square)

id(square)
# Out:
# 138819994083520

# %%
# reassign
x = square
id(x)
x(3)
# Out:
# 9

# %%
# deleting a function
del square

# %%
# storing
list = [1,2,3,4,square]
list
# Out:
# [1, 2, 3, 4, <function __main__.square(num)>]

# %%
# functions as argument
def func_a():
    print('inside func_a')

def func_b(z):
    print('inside func_b')
    return z()

print(func_b(func_a))

# %% [markdown]
# ### **Benefits of using a Function**
#
# *   Code Readibility
# *   Code Reusability
