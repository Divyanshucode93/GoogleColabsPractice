# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshucode93/GoogleColabsPractice/blob/main/HealthcareStroke_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/healthcare-dataset-stroke-data.csv')

# %% [markdown]
# # **Set 1 (Questions 1–10)**
# **Data Inspection & Basic Selection**

# %%
# Load the dataset healthcare-dataset-stroke-data.csv into a pandas DataFrame named df.
df    # df = pd.read_csv('/content/healthcare-dataset-stroke-data.csv')
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# Display the first 5 rows of the DataFrame.
df.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# How can you find the total number of rows and columns (the shape) of the dataset?
rows = df.shape[0]
columns = df.shape[1]

# %%
# Write the code to display the data types of all columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# Check the dataset for any missing (null) values and show the count of nulls for each column.
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Display the summary statistics (mean, standard deviation, min, max, etc.) for the numerical columns.
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
# Select and display only the gender column from the DataFrame.
df['gender']
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3       Female
# 4       Female
#          ...
# 5105    Female
# 5106    Female
# 5107    Female
# 5108      Male
# 5109    Female
# Name: gender, Length: 5110, dtype: object

# %%
# How do you display exactly the last 10 rows of the dataset?
df.tail(10)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5100  68398    Male  82.0             1              0          Yes
# 5101  36901  Female  45.0             0              0          Yes
# 5102  45010  Female  57.0             0              0          Yes
# 5103  22127  Female  18.0             0              0           No
# 5104  14180  Female  13.0             0              0           No
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5100  Self-employed          Rural              71.97  28.3     never smoked
# ...

# %%
# Find the count of each unique value in the smoking_status column (e.g., how many "smokes", "never smoked", etc.).
df['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %%
# Create a new variable called subset that contains only the age and stroke columns from the original DataFrame.
subset = df[['age','stroke']]
subset
# Out:
#        age  stroke
# 0     67.0       1
# 1     61.0       1
# 2     80.0       1
# 3     49.0       1
# 4     79.0       1
# ...    ...     ...
# 5105  80.0       0
# 5106  81.0       0
# 5107  35.0       0
# 5108  51.0       0
# 5109  44.0       0
#
# [5110 rows x 2 columns]

# %% [markdown]
# # **Set 2 (Questions 11-20)**
# Filtering, Sorting, and Column Operations

# %%
# Filter the DataFrame to show only the records where the age is 65 or older.
df[df['age'] >= 65]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# 6     53882    Male  74.0             1              1          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5092  56799    Male  76.0             0              0          Yes
# 5097  64520    Male  68.0             0              0          Yes
# 5100  68398    Male  82.0             1              0          Yes
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# Find the average (mean) bmi of the individuals in the dataset.
df['bmi'].mean()
# Out:
# np.float64(28.893236911794666)

# %%
# Sort the entire DataFrame by avg_glucose_level in descending order (highest values first).
df.sort_values('avg_glucose_level',ascending=False)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 193   69112    Male  68.0             1              1          Yes
# 1207  22440  Female  49.0             0              0          Yes
# 3088  26267  Female  76.0             0              0          Yes
# 4983  10995    Male  76.0             1              0          Yes
# 2462  27626  Female  60.0             0              0           No
# ...     ...     ...   ...           ...            ...          ...
# 772   72547    Male  61.0             0              0          Yes
# 682   61300    Male  20.0             0              0           No
# 4110  43028    Male  66.0             0              0          Yes
# 1191  37404    Male  42.0             0              0          Yes
# 4886  60562  Female  21.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# Rename the column Residence_type to residence_area.
df.rename(columns={'Residence_type':'residence_area'},inplace=True)
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type residence_area  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Create a new column called age_in_months by multiplying the age column by 12.
df['age_in_months'] = df['age'] * 12
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type residence_area  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  age_in_months
# 0       1          804.0
# 1       1          732.0
# 2       1          960.0
# ...

# %%
# How many people in this dataset have had a stroke (where stroke == 1)?
strokeone = df['stroke'] == 1
strokeone.sum()
# Out:
# np.int64(249)

# %%
# Drop the id column from the DataFrame permanently (inplace or by reassigning).
df.drop('id',axis=1,inplace=True)

# %%
# Filter the dataset to show only "Female" patients who also have "hypertension".
df[(df['gender'] == 'Female') & (df['hypertension'] == 1)]
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 4     Female  79.0             1              0          Yes  Self-employed
# 10    Female  81.0             1              0          Yes        Private
# 15    Female  50.0             1              0          Yes  Self-employed
# 21    Female  52.0             1              0          Yes  Self-employed
# 32    Female  82.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 4937  Female  62.0             1              0          Yes  Self-employed
# 4941  Female  51.0             1              0          Yes  Self-employed
# 5088  Female  64.0             1              0          Yes  Self-employed
# 5093  Female  45.0             1              0          Yes       Govt_job
# 5105  Female  80.0             1              0          Yes        Private
#
# ...

# %%
# What is the maximum value in the bmi column?
df['bmi'].max()
# Out:
# 97.6

# %%
# Check for null values again, but this time, calculate the percentage of missing values in each column rather than just the count.
(df.isna().sum() / len(df)) * 100
# Out:
# gender               0.000000
# age                  0.000000
# hypertension         0.000000
# heart_disease        0.000000
# ever_married         0.000000
# work_type            0.000000
# residence_area       0.000000
# avg_glucose_level    0.000000
# bmi                  3.933464
# smoking_status       0.000000
# stroke               0.000000
# age_in_months        0.000000
# dtype: float64

# %% [markdown]
# # **Set 3 (Questions 21-30)**
# **Advanced Filtering & Logic**

# %%
# Sort the DataFrame first by gender (ascending) and then by age (descending) in a single command.
df.sort_values(by=['gender','age'],ascending=[True,False])
# Out:
#       gender    age  hypertension  heart_disease ever_married      work_type  \
# 32    Female  82.00             1              0          Yes  Self-employed
# 35    Female  82.00             1              1           No        Private
# 56    Female  82.00             0              0          Yes        Private
# 187   Female  82.00             1              1          Yes       Govt_job
# 337   Female  82.00             0              1           No        Private
# ...      ...    ...           ...            ...          ...            ...
# 3618    Male   0.16             0              0           No       children
# 3968    Male   0.16             0              0           No       children
# 4021    Male   0.16             0              0           No       children
# 3295    Male   0.08             0              0           No       children
# 3116   Other  26.00             0              0           No        Private
#
# ...

# %%
# Use the .rename() method to change bmi to Body_Mass_Index and stroke to Stroke_Result simultaneously.
df.rename(columns={'bmi':'Body_Mass_Index','stroke':'Stroke_Result'},inplace=True)

# %%
# Calculate the percentage of the total population that is "Male".
perc = ((df['gender']=='Male').sum()) / (df.shape[0]) * 100
perc
# Out:
# np.float64(41.3894324853229)

# %%
# Filter the data to find patients who are "Private" workers AND have an avg_glucose_level greater than 200.
df[(df['work_type']=='Private') & (df['avg_glucose_level']>200)]
# Out:
#       gender   age  hypertension  heart_disease ever_married work_type  \
# 0       Male  67.0             0              1          Yes   Private
# 13      Male  78.0             0              1          Yes   Private
# 14    Female  79.0             0              1          Yes   Private
# 17      Male  75.0             1              0          Yes   Private
# 23      Male  82.0             0              1          Yes   Private
# ...      ...   ...           ...            ...          ...       ...
# 5001  Female  70.0             0              0          Yes   Private
# 5029  Female  72.0             0              0          Yes   Private
# 5034  Female  79.0             0              0           No   Private
# 5035  Female  78.0             0              0          Yes   Private
# 5061    Male  41.0             0              0          Yes   Private
#
#      residence_area  avg_glucose_level  Body_Mass_Index   smoking_status  \
# ...

# %%
# Find the average age of people who have had a stroke vs. those who haven't (Use groupby).
df.groupby('Stroke_Result')['age'].mean()
# Out:
# Stroke_Result
# 0    41.971545
# 1    67.728193
# Name: age, dtype: float64

# %%
# Create a column named is_obese which is True if bmi is greater than 30, and False otherwise.
df['is_obese'] = df['Body_Mass_Index'] > 30
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   residence_area  avg_glucose_level  Body_Mass_Index   smoking_status  \
# 0          Urban             228.69             36.6  formerly smoked
# 1          Rural             202.21              NaN     never smoked
# 2          Rural             105.92             32.5     never smoked
# 3          Urban             171.23             34.4           smokes
# 4          Rural             174.12             24.0     never smoked
#
#    Stroke_Result  age_in_months  is_obese
# 0              1          804.0      True
# ...

# %%
# Count how many unique values exist in the work_type column.
df['work_type'].nunique()
# Out:
# 5

# %%
# Retrieve the 5th to 15th rows of the DataFrame using .iloc.
df.iloc[4:15]
# Out:
#     gender   age  hypertension  heart_disease ever_married      work_type  \
# 4   Female  79.0             1              0          Yes  Self-employed
# 5     Male  81.0             0              0          Yes        Private
# 6     Male  74.0             1              1          Yes        Private
# 7   Female  69.0             0              0           No        Private
# 8   Female  59.0             0              0          Yes        Private
# 9   Female  78.0             0              0          Yes        Private
# 10  Female  81.0             1              0          Yes        Private
# 11  Female  61.0             0              1          Yes       Govt_job
# 12  Female  54.0             0              0          Yes        Private
# 13    Male  78.0             0              1          Yes        Private
# 14  Female  79.0             0              1          Yes        Private
#
#    residence_area  avg_glucose_level  Body_Mass_Index   smoking_status  \
# ...

# %%
# Filter for patients who are either "formerly smoked" or "smokes". (Hint: try using .isin()).
df[df['smoking_status'].isin(['formerly smoked','smokes'])]
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 5       Male  81.0             0              0          Yes        Private
# 11    Female  61.0             0              1          Yes       Govt_job
# 12    Female  54.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5087  Female  63.0             0              0          Yes  Self-employed
# 5090    Male  26.0             0              0           No       Govt_job
# 5093  Female  45.0             1              0          Yes       Govt_job
# 5099    Male  40.0             0              0          Yes        Private
# 5108    Male  51.0             0              0          Yes        Private
#
# ...

# %%
# Fill all the missing values in the bmi column with the median value of that column.
df['Body_Mass_Index'].fillna(value=df['Body_Mass_Index'].median(),inplace=True)
df
# Out:
# /tmp/ipython-input-3132492813.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Body_Mass_Index'].fillna(value=df['Body_Mass_Index'].median(),inplace=True)
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# ...

# %% [markdown]
# # **Set 4 (Questions 31-40)**
# **Vectorization, Pivot Tables, and Indexing**

# %%
# Use the df.loc accessor to filter for patients with age > 70 and only display the gender and Stroke_Result columns.
df.loc[(df['age'] > 70),['gender','Stroke_Result']]
# Out:
#       gender  Stroke_Result
# 2       Male              1
# 4     Female              1
# 5       Male              1
# 6       Male              1
# 9     Female              1
# ...      ...            ...
# 5085  Female              0
# 5092    Male              0
# 5100    Male              0
# 5105  Female              0
# 5106  Female              0
#
# [710 rows x 2 columns]

# %%
# The df.apply() method is very common. Create the is_obese column again, but this time use a lambda function applied to the Body_Mass_Index column.
# df.drop(columns='is_obese',inplace=True)
df['is_obese'] = df['Body_Mass_Index'].apply(lambda x: x > 30)
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
# Create a Pivot Table showing the average avg_glucose_level for each combination of gender and smoking_status.
# df.groupby(['gender','smoking_status'])['avg_glucose_level'].mean()
df.pivot_table(index='gender',columns='smoking_status',values='avg_glucose_level',aggfunc='mean')
# Out:
# smoking_status     Unknown  formerly smoked  never smoked      smokes
# gender
# Female           98.049306       104.599874    106.793263  107.161062
# Male            101.434407       122.522629    108.975852  109.166053
# Other                  NaN       143.330000           NaN         NaN

# %%
# Fill the missing values in Body_Mass_Index with the median value and ensure the change is saved in the original df.
df['Body_Mass_Index'] = df['Body_Mass_Index'].fillna(value=df['Body_Mass_Index'].median())
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   residence_area  avg_glucose_level  Body_Mass_Index   smoking_status  \
# 0          Urban             228.69             36.6  formerly smoked
# 1          Rural             202.21             28.1     never smoked
# 2          Rural             105.92             32.5     never smoked
# 3          Urban             171.23             34.4           smokes
# 4          Rural             174.12             24.0     never smoked
#
#    Stroke_Result  age_in_months  is_obese
# 0              1          804.0      True
# ...

# %%
# Create a new column called risk_score which is calculated as age divided by avg_glucose_level.
df['risk_score'] = df['age']/df['avg_glucose_level']
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   residence_area  avg_glucose_level  Body_Mass_Index   smoking_status  \
# 0          Urban             228.69             36.6  formerly smoked
# 1          Rural             202.21             28.1     never smoked
# 2          Rural             105.92             32.5     never smoked
# 3          Urban             171.23             34.4           smokes
# 4          Rural             174.12             24.0     never smoked
#
#    Stroke_Result  age_in_months  is_obese  risk_score
# ...

# %%
# Use the nlargest() method to find the top 5 oldest people in the dataset.
df.nlargest(n=5, columns='age')
# Out:
#     gender   age  hypertension  heart_disease ever_married      work_type  \
# 23    Male  82.0             0              1          Yes        Private
# 32  Female  82.0             1              0          Yes  Self-employed
# 35  Female  82.0             1              1           No        Private
# 42    Male  82.0             0              1          Yes        Private
# 56  Female  82.0             0              0          Yes        Private
#
#    residence_area  avg_glucose_level  Body_Mass_Index   smoking_status  \
# 23          Rural             208.30             32.5          Unknown
# 32          Urban             196.92             22.2     never smoked
# 35          Rural              84.03             26.5  formerly smoked
# 42          Urban             144.90             26.4           smokes
# 56          Rural              59.32             33.2     never smoked
#
#     Stroke_Result  age_in_months  is_obese  risk_score
# ...

# %%
# How many rows have a Body_Mass_Index that is higher than the average Body_Mass_Index of the whole dataset?
(df['Body_Mass_Index'] > df['Body_Mass_Index'].mean()).sum()
# Out:
# np.int64(2212)

# %%
# Change the data type of the Stroke_Result column from integer to string (object).
df['Stroke_Result'] = df['Stroke_Result'].astype(object)

# %%
# Use value_counts(normalize=True) on the work_type column to see the proportion (percentage) of each work type.
df['work_type'].value_counts(normalize=True)
# Out:
# work_type
# Private          0.572407
# Self-employed    0.160274
# children         0.134442
# Govt_job         0.128571
# Never_worked     0.004305
# Name: proportion, dtype: float64

# %%
# Select all rows where smoking_status is NOT "Unknown".
df[df['smoking_status']!='Unknown']
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5102  Female  57.0             0              0          Yes        Private
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
#
# ...

# %% [markdown]
# # **Set 5 (Questions 41-50)**
# **Persistence, Pivot Tables, and Binning**

# %%
# Permanent change: Convert the age column from float to int and save the change to df
df['age'] = df['age'].astype('int64')

# %%
# Create a Pivot Table that shows the count (not average) of people, grouped by work_type in rows and ever_married in columns.
df.pivot_table(index='work_type',columns='ever_married',values='gender',aggfunc='count')
# Out:
# ever_married      No     Yes
# work_type
# Govt_job       117.0   540.0
# Never_worked    22.0     NaN
# Private        821.0  2104.0
# Self-employed  110.0   709.0
# children       687.0     NaN

# %%
# Use the .str.upper() method to convert all strings in the gender column to uppercase permanently.
df['gender'] = df['gender'].str.upper()

# %%
# Create a new column called age_group by binning the age column into 3 categories: "Child" (0-18), "Adult" (19-60), and "Senior" (61-100). (Hint: Use pd.cut).
df['age_group'] = pd.cut(df['age'],3,labels=['Child','Adult','Senior'])

# %%
# Find the 10th row of the DataFrame using .iloc and display it as a Series.
df.iloc[[11]]
# Out:
#     gender  age  hypertension  heart_disease ever_married work_type  \
# 11  FEMALE   61             0              1          Yes  Govt_job
#
#    residence_area  avg_glucose_level  Body_Mass_Index smoking_status  \
# 11          Rural             120.46             36.8         smokes
#
#    Stroke_Result  age_in_months  is_obese  risk_score age_group
# 11             1          732.0      True    0.506392    Senior

# %%
# Create a variable high_risk that filters for rows where hypertension == 1 AND heart_disease == 1. How many such rows exist?
high_risk = df[(df['hypertension']==1) & (df['heart_disease']==1)]
high_risk.shape[0]
# Out:
# 64

# %%
# Use the .query() method to filter the DataFrame for patients who have an avg_glucose_level between 150 and 200.

# %%
# Calculate the correlation between age and Body_Mass_Index.

# %%
# Group the data by smoking_status and find the minimum and maximum avg_glucose_level for each group in a single operation.

# %%
# Reset the index of the DataFrame and drop the old index (ensure the change is permanent).
